# %% [markdown]
# # Bankruptcy Prediction
# ## Overview
# The dataset is about bankruptcy prediction of Polish companies. The data was collected from Emerging Markets Information Service (EMIS, ), which is a database containing information on emerging markets around the world. The bankrupt companies were analyzed in the period 2000-2012, while the still operating companies were evaluated from 2007 to 2013. The data contains 5910 instances (financial statements), 410 represents bankrupted companies, 5500 firms that did not bankrupt in the forecasting period. The dataset is downloaded from data.world (https://data.world/uci/polish-companies-bankruptcy-data)
# ## Variable Description
# * **X1**:	net profit / total assets
# * **X2**:	total liabilities / total assets
# * **X3**:	working capital / total assets
# * **X4**:	current assets / short-term liabilities
# * **X5**:	[(cash + short-term securities + receivables - short-term liabilities) / (operating expenses - depreciation)] * 365
# * **X6**:	retained earnings / total assets
# * **X7**:	EBIT / total assets
# * **X8**:	book value of equity / total liabilities
# * **X9**:	sales / total assets
# * **X10**:  equity / total assets
# * **X11**:	(gross profit + extraordinary items + financial expenses) / total assets
# * **X12**:	gross profit / short-term liabilities
# * **X13**:	(gross profit + depreciation) / sales
# * **X14**:	(gross profit + interest) / total assets
# * **X15**:	(total liabilities * 365) / (gross profit + depreciation)
# * **X16**:	(gross profit + depreciation) / total liabilities
# * **X17**:	total assets / total liabilities
# * **X18**:	gross profit / total assets
# * **X19**:	gross profit / sales
# * **X20**:	(inventory * 365) / sales
# * **X21**:	sales (n) / sales (n-1)
# * **X22**:	profit on operating activities / total assets
# * **X23**:	net profit / sales
# * **X24**:	gross profit (in 3 years) / total assets
# * **X25**:	(equity - share capital) / total assets
# * **X26**:	(net profit + depreciation) / total liabilities
# * **X27**:	profit on operating activities / financial expenses
# * **X28**:	working capital / fixed assets
# * **X29**:	logarithm of total assets
# * **X30**:	(total liabilities - cash) / sales
# * **X31**:	(gross profit + interest) / sales
# * **X32**:  (current liabilities * 365) / cost of products sold
# * **X33**:	operating expenses / short-term liabilities
# * **X34**:	operating expenses / total liabilities
# * **X35**:	profit on sales / total assets
# * **X36**:	total sales / total assets
# * **X37**:	(current assets - inventories) / long-term liabilities
# * **X38**:	constant capital / total assets
# * **X39**:	profit on sales / sales
# * **X40**:	(current assets - inventory - receivables) / short-term liabilities
# * **X41**:	total liabilities / ((profit on operating activities + depreciation) * (12/365))
# * **X42**:	profit on operating activities / sales
# * **X43**:	rotation receivables + inventory turnover in days
# * **X44**:  (receivables * 365) / sales
# * **X45**:	net profit / inventory
# * **X46**:	(current assets - inventory) / short-term liabilities
# * **X47**:  (inventory * 365) / cost of products sold
# * **X48**:	EBITDA (profit on operating activities - depreciation) / total assets
# * **X49**:	EBITDA (profit on operating activities - depreciation) / sales
# * **X50**:	current assets / total liabilities
# * **X51**:  short-term liabilities / total assets
# * **X52**:	(short-term liabilities * 365) / cost of products sold)
# * **X53**:	equity / fixed assets
# * **X54**:	constant capital / fixed assets
# * **X55**:	working capital
# * **X56**:	(sales - cost of products sold) / sales
# * **X57**:	(current assets - inventory - short-term liabilities) / (sales - gross profit - depreciation)
# * **X58**:	total costs /total sales
# * **X59**:	long-term liabilities / equity
# * **X60**:	sales / inventory
# * **X61**:	sales / receivables
# * **X62**:	(short-term liabilities * 365) / sales
# * **X63**:  sales / short-term liabilities
# * **X64**:	sales / fixed assets

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
os.chdir(r'D:\Bank\Polish Companies Bankruptcy')

# %%
files = []
for i in range(1, 6):
    counter = str(i)
    name = counter + 'year.arff'
    files.append(name)
print("Files: ", files)
# Out:
# Files:  ['1year.arff', '2year.arff', '3year.arff', '4year.arff', '5year.arff']

# %%
from scipy.io import arff
file_data = []
for file in files:
    file_data.append(arff.loadarff(file))
print(file_data[0:2])
# Out:
# [(array([( 0.20055 , 0.37951,  0.39641, 2.0472 ,   32.351 , 0.38825 ,  0.24976 , 1.3305  , 1.1389 , 0.50494 , 0.24976 ,  0.6598  ,  0.1666  ,  0.24976 ,    497.42,  0.73378 , 2.6349,  0.24976 ,  0.14942 , 43.37  , 1.2479 , 0.21402 ,  0.11998 , 0.47706 , 0.50494 ,  0.60411 ,  1.4582 ,  1.7615 , 5.9443, 0.11788, 0.14942 ,  94.14 , 3.8772, 0.56393 ,  0.21402 , 1.741  , 5.9327e+02, 0.50591,  0.12804 , 0.66295 , 0.051402, 0.12804 , 114.42 ,  71.05 ,  1.0097  , 1.5225 ,  49.394 ,  0.1853  ,  0.11085 , 2.042  , 0.37854, 0.25792,  2.2437 ,  2.248  ,  3.4869e+05,  0.12196 ,  0.39718 , 0.87804, 1.9240e-03,  8.416 , 5.1372,  82.658, 4.4158,  7.4277 , b'0'),
# ...

# %%
for i in range(0, len(file_data)):
    if i==0:
        cb_df = pd.DataFrame.from_records(data = file_data[i][0])
        continue
    if i!=0:
        d = pd.DataFrame.from_records(data = file_data[i][0])
        cb_df = cb_df.append(d)

# %%
cb_df.shape
# Out:
# (43405, 65)

# %%
cb_df.head()
# Out:
#       Attr1    Attr2    Attr3   Attr4    Attr5    Attr6     Attr7    Attr8  \
# 0  0.200550  0.37951  0.39641  2.0472  32.3510  0.38825  0.249760  1.33050
# 1  0.209120  0.49988  0.47225  1.9447  14.7860  0.00000  0.258340  0.99601
# 2  0.248660  0.69592  0.26713  1.5548  -1.1523  0.00000  0.309060  0.43695
# 3  0.081483  0.30734  0.45879  2.4928  51.9520  0.14988  0.092704  1.86610
# 4  0.187320  0.61323  0.22960  1.4063  -7.3128  0.18732  0.187320  0.63070
#
#     Attr9   Attr10  ...      Attr56   Attr57   Attr58    Attr59  Attr60  \
# 0  1.1389  0.50494  ...    0.121960  0.39718  0.87804  0.001924  8.4160
# 1  1.6996  0.49788  ...    0.121300  0.42002  0.85300  0.000000  4.1486
# 2  1.3090  0.30408  ...    0.241140  0.81774  0.76599  0.694840  4.9909
# 3  1.0571  0.57353  ...    0.054015  0.14207  0.94598  0.000000  4.5746
# 4  1.1559  0.38677  ...    0.134850  0.48431  0.86515  0.124440  6.3985
#
#    Attr61   Attr62  Attr63   Attr64  class
# ...

# %%
cb_df.columns = map(str.lower, cb_df.columns)
cb_df['class'] = cb_df['class'].astype('int')
cb_df.head()
# Out:
#       attr1    attr2    attr3   attr4    attr5    attr6     attr7    attr8  \
# 0  0.200550  0.37951  0.39641  2.0472  32.3510  0.38825  0.249760  1.33050
# 1  0.209120  0.49988  0.47225  1.9447  14.7860  0.00000  0.258340  0.99601
# 2  0.248660  0.69592  0.26713  1.5548  -1.1523  0.00000  0.309060  0.43695
# 3  0.081483  0.30734  0.45879  2.4928  51.9520  0.14988  0.092704  1.86610
# 4  0.187320  0.61323  0.22960  1.4063  -7.3128  0.18732  0.187320  0.63070
#
#     attr9   attr10  ...      attr56   attr57   attr58    attr59  attr60  \
# 0  1.1389  0.50494  ...    0.121960  0.39718  0.87804  0.001924  8.4160
# 1  1.6996  0.49788  ...    0.121300  0.42002  0.85300  0.000000  4.1486
# 2  1.3090  0.30408  ...    0.241140  0.81774  0.76599  0.694840  4.9909
# 3  1.0571  0.57353  ...    0.054015  0.14207  0.94598  0.000000  4.5746
# 4  1.1559  0.38677  ...    0.134850  0.48431  0.86515  0.124440  6.3985
#
#    attr61   attr62  attr63   attr64  class
# ...

# %%
cb_df.reset_index()
cb_df.head()
# Out:
#       attr1    attr2    attr3   attr4    attr5    attr6     attr7    attr8  \
# 0  0.200550  0.37951  0.39641  2.0472  32.3510  0.38825  0.249760  1.33050
# 1  0.209120  0.49988  0.47225  1.9447  14.7860  0.00000  0.258340  0.99601
# 2  0.248660  0.69592  0.26713  1.5548  -1.1523  0.00000  0.309060  0.43695
# 3  0.081483  0.30734  0.45879  2.4928  51.9520  0.14988  0.092704  1.86610
# 4  0.187320  0.61323  0.22960  1.4063  -7.3128  0.18732  0.187320  0.63070
#
#     attr9   attr10  ...      attr56   attr57   attr58    attr59  attr60  \
# 0  1.1389  0.50494  ...    0.121960  0.39718  0.87804  0.001924  8.4160
# 1  1.6996  0.49788  ...    0.121300  0.42002  0.85300  0.000000  4.1486
# 2  1.3090  0.30408  ...    0.241140  0.81774  0.76599  0.694840  4.9909
# 3  1.0571  0.57353  ...    0.054015  0.14207  0.94598  0.000000  4.5746
# 4  1.1559  0.38677  ...    0.134850  0.48431  0.86515  0.124440  6.3985
#
#    attr61   attr62  attr63   attr64  class
# ...

# %%
X = cb_df.columns
y = cb_df.isnull().sum()
sns.set()
sns.set(rc={'figure.figsize':(22,10)})
sns.barplot(X,y)
ax = plt.gca()
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width()/2.,
            height + 2,
            int(height),
            fontsize=15, ha='center', va='bottom')
sns.set(font_scale=2)
ax.set_xlabel("Features")
ax.set_ylabel("Count of missing values for each feature")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **X37**: (current assets - inventories) / long-term liabilities<br>
# **X21**: sales (n) / sales (n-1)<br>
# These two features have maximum missing values.

# %%
total_len = len(cb_df['class'])
percentage_labels = (cb_df['class'].value_counts()/total_len)*100
percentage_labels
sns.set()
sns.countplot(cb_df['class']).set_title('Data Distribution for Target Variable')
ax = plt.gca()
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width()/2.,
            height + 2,
            '{:.2f}%'.format(100*(height/total_len)),
            fontsize=14, ha='center', va='bottom')
sns.set(font_scale=3)
ax.set_xlabel("Classes")
ax.set_ylabel("Frequency")
plt.show()

# %%
sns.set(style="white")
corr = cb_df.corr()
f, ax = plt.subplots(figsize=(18, 18))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, cmap=cmap, vmax=.3, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %%
cb_df1 = cb_df.fillna(cb_df.mean())
cb_df1.describe()
# Out:
#               attr1         attr2         attr3         attr4         attr5  \
# count  43405.000000  43405.000000  43405.000000  43405.000000  4.340500e+04
# mean       0.035160      0.590212      0.114431      6.314702 -3.853466e+02
# std        2.993833      5.842209      5.438928    294.978029  6.118020e+04
# min     -463.890000   -430.870000   -479.960000     -0.403110 -1.190300e+07
# 25%        0.003434      0.269010      0.021540      1.050800 -4.949000e+01
# 50%        0.049636      0.471940      0.196580      1.574000 -1.184000e+00
# 75%        0.129560      0.688270      0.403260      2.806000  5.046100e+01
# max       94.280000    480.960000     28.336000  53433.000000  1.250100e+06
#
#               attr6         attr7         attr8         attr9        attr10  \
# count  43405.000000  43405.000000  43405.000000  43405.000000  43405.000000
# mean      -0.056107      0.093478     12.640779      2.652166      0.626868
# ...

# %% [markdown]
# We will scale all the features because they are not in the same range. Not doing so might affect the performance of our model.

# %%
X = cb_df1.drop('class', axis=1)
y= cb_df1['class']

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X_std = ss.fit_transform(X)

# %% [markdown]
# Split the data using stratify parameter = y to ensure that class distribution for the target is kept constant during the split.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_std, y, test_size=0.2, stratify=y, random_state = 0)

# %% [markdown]
# ### Define a cvDictGen function to compare initial models

# %%
from sklearn.model_selection import cross_val_score
def cvDictGen(functions, scr, X_train, y_train, cv=5, verbose=1):
    cvDict = {}
    for func in functions:
        cvScore = cross_val_score(func, X_train, y_train, cv=cv, verbose=verbose, scoring=scr)
        cvDict[str(func).split('(')[0]] = [cvScore.mean(), cvScore.std()]
    return cvDict

# %% [markdown]
# ## Machine Learning

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
lr = LogisticRegression(penalty='l1', dual=False, tol=0.0001, C=1.0, fit_intercept=True, intercept_scaling=1, 
                        class_weight=None, random_state=None, solver='liblinear', max_iter=100, multi_class='ovr', verbose=2)
rf = RandomForestClassifier(n_estimators=10, criterion='gini', max_depth=None, min_samples_split=2, 
                            min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features='auto', max_leaf_nodes=None,
                            bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0)

# %%
cvd = cvDictGen(functions=[lr, rf], X_train = X_train, y_train= y_train, scr='roc_auc')
cvd
# Out:
# [LibLinear][LibLinear][LibLinear]
# C:\Users\Prabodh\Anaconda2\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# C:\Users\Prabodh\Anaconda2\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:898: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [LibLinear]
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  8.4min finished
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   16.9s finished
# {'LogisticRegression': [0.7009006652287232, 0.014459090110615042],
#  'RandomForestClassifier': [0.8617584413140886, 0.01221855605486194]}

# %%
# Random Forest Classifier
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
test_labels = rf.predict_proba(np.array(X_test))[:,1]

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, roc_auc_score

# %%
print('Random Forest')
print('ROC AUC Score: ', roc_auc_score(y_test, test_labels))
print('Precision:', precision_score(y_test, y_pred))
# Out:
# Random Forest
# ROC AUC Score:  0.8567387217011095
# Precision: 0.831081081081081

# %%
def Confusion_Matrix(CMatrix, labels=['operating','bankrupt']):
    df = pd.DataFrame(data=CMatrix, index=labels, columns=labels)
    df.index.name='TRUE'
    df.columns.name='PREDICTION'
    df.loc['Total'] = df.sum()
    df['Total'] = df.sum(axis=1)
    return df

# %%
RF_CMatrix = confusion_matrix(y_test, y_pred)

# %%
Confusion_Matrix(RF_CMatrix)
# Out:
# PREDICTION  operating  bankrupt  Total
# TRUE
# operating        8238        25   8263
# bankrupt          295       123    418
# Total            8533       148   8681

# %% [markdown]
# ### XGBoost

# %%
from xgboost.sklearn import XGBClassifier
xgb1 = XGBClassifier(
 learning_rate =0.1,
 n_estimators=1000,
 max_depth=5,
 min_child_weight=1,
 gamma=0,
 subsample=0.8,
 colsample_bytree=0.8,
 objective= 'binary:logistic',
 nthread=4,
 scale_pos_weight=35, #obtained from trial and error
 seed=0)

# %%
xgb1.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=5, min_child_weight=1, missing=None, n_estimators=1000,
#        n_jobs=1, nthread=4, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=35, seed=0, silent=True,
#        subsample=0.8)

# %%
y_pred_xgb = xgb1.predict(X_test)
predictions = [round(value) for value in y_pred_xgb]
Confusion_Matrix(confusion_matrix(y_test, predictions))
# Out:
# C:\Users\Prabodh\Anaconda2\envs\tensorflow\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# PREDICTION  operating  bankrupt  Total
# TRUE
# operating        8207        56   8263
# bankrupt          141       277    418
# Total            8348       333   8681

# %%
roc_auc_score(y_test, predictions)
# Out:
# 0.8279511131364988

# %%
xgb2 = XGBClassifier(
 learning_rate =0.05,
 n_estimators=1400,
 max_depth=3,
 min_child_weight=10,
 gamma=1.5,
 subsample=0.6,
 colsample_bytree=1.0,
 objective= 'binary:logistic',
 nthread=8,
 scale_pos_weight=35, #obtained from trial and error
 seed=0)

# %%
xgb2.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1.0, gamma=1.5, learning_rate=0.05,
#        max_delta_step=0, max_depth=3, min_child_weight=10, missing=None,
#        n_estimators=1400, n_jobs=1, nthread=8, objective='binary:logistic',
#        random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=35,
#        seed=0, silent=True, subsample=0.6)

# %%
y_pred_xgb_best = xgb2.predict(X_test)
predictions_best = [round(value) for value in y_pred_xgb_best]
Confusion_Matrix(confusion_matrix(y_test, predictions_best))
# Out:
# C:\Users\Prabodh\Anaconda2\envs\tensorflow\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# PREDICTION  operating  bankrupt  Total
# TRUE
# operating        7843       420   8263
# bankrupt           79       339    418
# Total            7922       759   8681

# %%
roc_auc_score(y_test, predictions_best)
# Out:
# 0.8800878939782868

# %%
features_label = X.columns
feature_list = dict(zip(features_label, xgb2.feature_importances_*100))

# %%
top_ten_features = sorted(feature_list, key=feature_list.__getitem__, reverse= True)[:11]
top_ten_features
# Out:
# ['attr27',
#  'attr46',
#  'attr5',
#  'attr58',
#  'attr34',
#  'attr24',
#  'attr29',
#  'attr55',
#  'attr25',
#  'attr21',
#  'attr36']

# %% [markdown]
# * **X27**: profit on operating activities / financial expenses
# * **X46**: (current assets - inventory) / short-term liabilities
# * **X5**: [(cash + short-term securities + receivables - short-term liabilities) / (operating expenses - depreciation)] * 365
# * **X58**: total costs /total sales
# * **X34**: operating expenses / total liabilities
# * **X24**: gross profit (in 3 years) / total assets
# * **X29**: logarithm of total assets
# * **X55**: working capital
# * **X25**: (equity - share capital) / total assets
# * **X21**: sales (n) / sales (n-1)
# * **X36**: total sales / total assets
